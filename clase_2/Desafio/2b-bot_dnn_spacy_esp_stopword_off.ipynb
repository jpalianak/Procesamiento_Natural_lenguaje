# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Bot basado en reglas con DNN + Spacy

# %% [markdown]
# #### Datos
# Este ejemplo se inspiró en otro Bot en inglés creado con NLTK, lo tienen como referencia para hacer lo mismo en inglés:\
# [LINK](https://towardsdatascience.com/a-simple-chatbot-in-python-with-deep-learning-3e8669997758)

# %% [markdown]
# ### 1 - Instalar dependencias
# Para poder utilizar Spacy en castellano es necesario agregar la librería "spacy-stanza" para lematizar palabras en español.

# %%
# La última versión de spacy-stanza (>1.0) es compatible solo con spacy >=3.0
# Nota: spacy 3.0 incorpora al pepiline nlp transformers
# !pip install -U spacy --quiet
#!pip install -U spacy==3.1 --quiet
# !pip install -U spacy-stanza==1.0.0 --quiet

# %%
import json
import string
import random 
import numpy as np

import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout

# %%
import stanza
import spacy_stanza

# Vamos a usar SpaCy-Stanza. Stanza es una librería de NLP de Stanford
# SpaCy armó un wrapper para los pipelines y modelos de Stanza
# https://stanfordnlp.github.io/stanza/

# Descargar el diccionario en español y armar el pipeline de NLP con spacy
stanza.download("es")
nlp = spacy_stanza.load_pipeline("es")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# INFO:stanza:Downloading default packages for language: es (Spanish)...
# INFO:stanza:File exists: /root/stanza_resources/es/default.zip.
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %% [markdown]
# ### 2 - Herramientas de preprocesamiento de datos
# Entre las tareas de procesamiento de texto en español se implementa:
# - Quitar acentos y caracteres especiales
# - Quitar números
# - Quitar símbolos de puntuación

# %%
import re
import unicodedata

# El preprocesamento en castellano requiere más trabajo

# Referencia de regex:
# https://docs.python.org/3/library/re.html

def preprocess_clean_text(text):    
    # sacar tildes de las palabras:
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    # quitar caracteres especiales
    pattern = r'[^a-zA-z0-9.,!?/:;\"\'\s]' # [^ : ningún caracter de todos estos
    # (termina eliminando cualquier caracter distinto de los del regex)
    text = re.sub(pattern, '', text)
    pattern = r'[^a-zA-z.,!?/:;\"\'\s]' # igual al anterior pero sin cifras numéricas
    # quitar números
    text = re.sub(pattern, '', text)
    # quitar caracteres de puntuación
    text = ''.join([c for c in text if c not in string.punctuation])
    return text

# %% [markdown]
# ### 3 - Diccionario de entrada

# %%
# Dataset en formato JSON que representa las posibles preguntas (patterns)
# y las posibles respuestas por categoría (tag)
# Los "patterns" van a formar el corpus para entrenar el clasificador que clasifica en tags
# "respones" son las respuestas predeterminadas posibles para cada tag
dataset = {"intents": [
             {"tag": "bienvenida",
              "patterns": ["Hola","¿Cómo estás?", "¿Qué tal?"],
              "responses": ["Hola!", "Hola, ¿Cómo estás?"]
             },
             {"tag": "bienvenida1",
              "patterns": ["Buen dia","Hola, buen dia"],
              "responses": ["Hola, buen dia!", "Buen dia, ¿Cómo estás?"]
             },
             {"tag": "bienvenida2",
              "patterns": ["Buenas tardes","Hola, buenas tardes"],
              "responses": ["Hola, buen buenas tardes!", "Buenas tardes, ¿Cómo estás?"]
             },
             {"tag": "producto",
              "patterns": ["Necesito fabricar palieres", "¿Fabrican palieres?","¿Tienen palieres?", "Necesito un juego de palieres"],
              "responses": ["Si, ¿para que categoria?","Si, para que auto?"]
             },
             {"tag": "producto1",
              "patterns": ["¿Que debo enviar para fabricarlos?", "¿Como debo hacer para encargarlos?"],
              "responses": ["Necesitamos la muestra para poder fabricarlo"]
             },
             {"tag": "plazo",
              "patterns": ["¿Que demora tienen?", "¿Cuanto tardan?", "¿Plazo de entrega?"],
              "responses": ["En material estandar 15 dias, en material PRO 25 dias"]
              },
             {"tag": "plazo",
              "patterns": ["¿Que debo enviar para fabricarlos?", "¿Como debo hacer para encargarlos?"],
              "responses": ["Necesitamos la muestra para poder fabricarlo"]
             },
            {"tag": "categoria",
              "patterns": ["TC","TC2000","Turismo nacional","Top race","Picadas", "Turismo pista","Zonal"],
              "responses": ["ok, algunos modelos los tenemos en stock, otros los fabricamos segun muestra"]
             },
             {"tag": "contacto",
              "patterns": ["contacto", "número de contacto", "número de teléfono", "número de whatsapp", "whatsapp"],
              "responses": ["Podes contactarnos al telefono 000-0000000", "Contactos al whatsapp 000-0000000"]
             },
            {"tag": "precios",
              "patterns": ["precio", "Me podrás pasar los precios", "¿Cuánto vale?", "¿Cuánto sale?"],
              "responses": ["En el siguiente link podrás encontrar los precios de todos nuestros productos en stock"]
             },
            {"tag": "pagos",
              "patterns": ["medios de pago", "tarjeta de crédito", "tarjetas", "cuotas"],
              "responses": ["A traves de transferencia bancaria"]
             },
            {"tag": "agradecimientos",
              "patterns": [ "Muchas gracias", "Gracias"],
              "responses": ["Por nada!, cualquier otra consulta podes escribirme"]
             },
             {"tag": "despedida",
              "patterns": [ "Chau", "Hasta luego!"],
              "responses": ["Hasta luego!", "Hablamos luego!"]
             }
]}

# %% [markdown]
# ### 4 - Preprocesamiento y armado del dataset

# %%
# Datos que necesitaremos, las palabras o vocabulario
words = []
classes = []
doc_X = []
doc_y = []

# Por cada intención (intents) debemos tomar los patrones que la caracterízan
# a esa intención y transformarla a tokens para almacenar en doc_X

# El tag de cada intención se almacena como doc_Y (la clase a predecir)
# En `words` vamos a guardar el vocabulario
# En `class` las posibles clases o tags

for intent in dataset["intents"]:
    for pattern in intent["patterns"]:
        # trasformar el patron a tokens
        tokens = nlp(preprocess_clean_text(pattern.lower()))
        # lematizar los tokens
        for token in tokens:       
            words.append(token.lemma_)
        
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # Agregar el tag a las clases
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# Elminar duplicados con "set" y ordenar el vocubulario y las clases por orden alfabético
words = sorted(set(words))
classes = sorted(set(classes))
# Out:
# /usr/local/lib/python3.7/dist-packages/stanza/models/common/beam.py:86: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   prevK = bestScoresId // numWords

# %%
print("words:", words)
print("classes:", classes)
print("doc_X:", doc_X)
print("doc_y:", doc_y)
# Out:
# words: ['buen', 'chau', 'como', 'contacto', 'credito', 'cuanto', 'cuota', 'de', 'deber', 'demora', 'dia', 'el', 'encargar', 'entrega', 'enviar', 'este', 'fabricar', 'gracias', 'hacer', 'hasta', 'holar', 'juego', 'luego', 'medio', 'mucho', 'nacional', 'necesitar', 'numero', 'pago', 'palier', 'para', 'pasar', 'picada', 'pista', 'plazo', 'poder', 'precio', 'que', 'race', 'salir', 'tal', 'tardar', 'tarde', 'tarjeta', 'tc', 'telefono', 'tener', 'top', 'turismo', 'uno', 'valer', 'whatsapp', 'yo', 'zonal', 'él']
# classes: ['agradecimientos', 'bienvenida', 'bienvenida1', 'bienvenida2', 'categoria', 'contacto', 'despedida', 'pagos', 'plazo', 'precios', 'producto', 'producto1']
# doc_X: ['Hola', '¿Cómo estás?', '¿Qué tal?', 'Buen dia', 'Hola, buen dia', 'Buenas tardes', 'Hola, buenas tardes', 'Necesito fabricar palieres', '¿Fabrican palieres?', '¿Tienen palieres?', 'Necesito un juego de palieres', '¿Que debo enviar para fabricarlos?', '¿Como debo hacer para encargarlos?', '¿Que demora tienen?', '¿Cuanto tardan?', '¿Plazo de entrega?', '¿Que debo enviar para fabricarlos?', '¿Como debo hacer para encargarlos?', 'TC', 'TC2000', 'Turismo nacional', 'Top race', 'Picadas', 'Turismo pista', 'Zonal', 'contacto', 'número de contacto', 'número de teléfono', 'número de whatsapp', 'whatsapp', 'precio', 'Me podrás pasar los precios', '¿Cuánto vale?', '¿Cuánto sale?', 'medios de pago', 'tarjeta de crédito', 'tarjetas', 'cuotas', 'Muchas gracias', 'Gracias', 'Chau', 'Hasta luego!']
# doc_y: ['bienvenida', 'bienvenida', 'bienvenida', 'bienvenida1', 'bienvenida1', 'bienvenida2', 'bienvenida2', 'producto', 'producto', 'producto', 'producto', 'producto1', 'producto1', 'plazo', 'plazo', 'plazo', 'plazo', 'plazo', 'categoria', 'categoria', 'categoria', 'categoria', 'categoria', 'categoria', 'categoria', 'contacto', 'contacto', 'contacto', 'contacto', 'contacto', 'precios', 'precios', 'precios', 'precios', 'pagos', 'pagos', 'pagos', 'pagos', 'agradecimientos', 'agradecimientos', 'despedida', 'despedida']

# %%
# Tamaño del vocabulario
print("Vocabulario:", len(words))
# Out:
# Vocabulario: 55

# %%
# Cantidad de tags
print("Tags:", len(classes))
# Out:
# Tags: 12

# %%
# Transformar doc_X en bag of words por oneHotEncoding
# Transformar doc_Y en un vector de clases multicategórico con oneHotEncoding

training = []
out_empty = [0] * len(classes)

for idx, doc in enumerate(doc_X):

    # Transformar la pregunta (input) en tokens y lematizar
    text = []
    tokens = nlp(preprocess_clean_text(doc.lower()))

    for token in tokens:
        text.append(token.lemma_)

    # Transformar los tokens en "Bag of words" (arrays de 1 y 0)
    bow = []
    for word in words:
        bow.append(1) if word in text else bow.append(0)

    # Crear el array de salida (class output) correspondiente
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1

    #print("X:", bow, "y:", output_row)
    training.append([bow, output_row])

# Mezclar los datos
random.shuffle(training)
training = np.array(training, dtype=object)
# Dividir en datos de entrada y salida
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %% [markdown]
# ### 5 - Entrenamiento del modelo

# %%
# Shape de entrada y salida
input_shape = (train_X.shape[1],)
output_shape = train_y.shape[1]
print("input:", input_shape, "output:", output_shape)
# Out:
# input: (55,) output: 12

# %%
# Entrenamiento del modelo DNN
# - Modelo secuencial
# - Con regularización
# - softmax y optimizador Adam
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(output_shape, activation = "softmax"))

model.compile(loss='categorical_crossentropy',
              optimizer="Adam",
              metrics=["accuracy"])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7168
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 16,204
# Trainable params: 16,204
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
hist = model.fit(x=train_X, y=train_y, epochs=200)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 9ms/step - loss: 2.4767 - accuracy: 0.0476
# Epoch 2/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4789 - accuracy: 0.1190
# Epoch 3/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4765 - accuracy: 0.1190
# Epoch 4/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.5059 - accuracy: 0.0952
# Epoch 5/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4223 - accuracy: 0.0952
# Epoch 6/200
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4642 - accuracy: 0.1190
# Epoch 7/200
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4297 - accuracy: 0.1429
# Epoch 8/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3806 - accuracy: 0.1667
# Epoch 9/200
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4032 - accuracy: 0.2143
# Epoch 10/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.3765 - accuracy: 0.1905
# Epoch 11/200
# 2/2 [==============================] - 0s 9ms/step - loss: 2.3648 - accuracy: 0.1667
# Epoch 12/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.3471 - accuracy: 0.1667
# Epoch 13/200
# 2/2 [==============================] - 0s 16ms/step - loss: 2.3654 - accuracy: 0.1667
# Epoch 14/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.3218 - accuracy: 0.2381
# Epoch 15/200
# 2/2 [==============================] - 0s 9ms/step - loss: 2.2853 - accuracy: 0.2857
# Epoch 16/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3218 - accuracy: 0.1667
# Epoch 17/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.2985 - accuracy: 0.3571
# Epoch 18/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2489 - accuracy: 0.2619
# Epoch 19/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.2404 - accuracy: 0.3810
# Epoch 20/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.2488 - accuracy: 0.2381
# Epoch 21/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2143 - accuracy: 0.4048
# Epoch 22/200
# 2/2 [==============================] - 0s 11ms/step - loss: 2.1398 - accuracy: 0.4048
# Epoch 23/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1330 - accuracy: 0.3810
# Epoch 24/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1481 - accuracy: 0.4286
# Epoch 25/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1418 - accuracy: 0.2857
# Epoch 26/200
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1269 - accuracy: 0.3571
# Epoch 27/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1108 - accuracy: 0.4762
# Epoch 28/200
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0200 - accuracy: 0.3810
# Epoch 29/200
# 2/2 [==============================] - 0s 13ms/step - loss: 2.0368 - accuracy: 0.5000
# Epoch 30/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0753 - accuracy: 0.4048
# Epoch 31/200
# 2/2 [==============================] - 0s 9ms/step - loss: 2.0725 - accuracy: 0.3571
# Epoch 32/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9969 - accuracy: 0.5238
# Epoch 33/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0331 - accuracy: 0.3333
# Epoch 34/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9217 - accuracy: 0.4762
# Epoch 35/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9953 - accuracy: 0.5000
# Epoch 36/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9262 - accuracy: 0.4762
# Epoch 37/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8705 - accuracy: 0.5952
# Epoch 38/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9062 - accuracy: 0.4762
# Epoch 39/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9010 - accuracy: 0.5238
# Epoch 40/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8662 - accuracy: 0.4762
# Epoch 41/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8444 - accuracy: 0.5238
# Epoch 42/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8202 - accuracy: 0.4286
# Epoch 43/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7932 - accuracy: 0.5238
# Epoch 44/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7614 - accuracy: 0.5238
# Epoch 45/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7798 - accuracy: 0.5952
# Epoch 46/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7068 - accuracy: 0.5952
# Epoch 47/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6176 - accuracy: 0.5952
# Epoch 48/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5840 - accuracy: 0.6190
# Epoch 49/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7009 - accuracy: 0.5476
# Epoch 50/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.6407 - accuracy: 0.5952
# Epoch 51/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5650 - accuracy: 0.6429
# Epoch 52/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6138 - accuracy: 0.5714
# Epoch 53/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6239 - accuracy: 0.5238
# Epoch 54/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6036 - accuracy: 0.5714
# Epoch 55/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4572 - accuracy: 0.5238
# Epoch 56/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5683 - accuracy: 0.5238
# Epoch 57/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4261 - accuracy: 0.6429
# Epoch 58/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5401 - accuracy: 0.5476
# Epoch 59/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5687 - accuracy: 0.6429
# Epoch 60/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5144 - accuracy: 0.5714
# Epoch 61/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4778 - accuracy: 0.5476
# Epoch 62/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4988 - accuracy: 0.6190
# Epoch 63/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3160 - accuracy: 0.7381
# Epoch 64/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2709 - accuracy: 0.7619
# Epoch 65/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3885 - accuracy: 0.6190
# Epoch 66/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3038 - accuracy: 0.7143
# Epoch 67/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2045 - accuracy: 0.7143
# Epoch 68/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2163 - accuracy: 0.7381
# Epoch 69/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2782 - accuracy: 0.7381
# Epoch 70/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2043 - accuracy: 0.7619
# Epoch 71/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2509 - accuracy: 0.7619
# Epoch 72/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1527 - accuracy: 0.7619
# Epoch 73/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2635 - accuracy: 0.6190
# Epoch 74/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1338 - accuracy: 0.7381
# Epoch 75/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1938 - accuracy: 0.7381
# Epoch 76/200
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1017 - accuracy: 0.6905
# Epoch 77/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0395 - accuracy: 0.7857
# Epoch 78/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1579 - accuracy: 0.7143
# Epoch 79/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0293 - accuracy: 0.7381
# Epoch 80/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9894 - accuracy: 0.8095
# Epoch 81/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9911 - accuracy: 0.7857
# Epoch 82/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9186 - accuracy: 0.8095
# Epoch 83/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1817 - accuracy: 0.6667
# Epoch 84/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9162 - accuracy: 0.7143
# Epoch 85/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0126 - accuracy: 0.8095
# Epoch 86/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9861 - accuracy: 0.8095
# Epoch 87/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9151 - accuracy: 0.8095
# Epoch 88/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9927 - accuracy: 0.7381
# Epoch 89/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9613 - accuracy: 0.7381
# Epoch 90/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9907 - accuracy: 0.7619
# Epoch 91/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8232 - accuracy: 0.8095
# Epoch 92/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8649 - accuracy: 0.8095
# Epoch 93/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7148 - accuracy: 0.8095
# Epoch 94/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8583 - accuracy: 0.7619
# Epoch 95/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7616 - accuracy: 0.7857
# Epoch 96/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7796 - accuracy: 0.8333
# Epoch 97/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8479 - accuracy: 0.7857
# Epoch 98/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7354 - accuracy: 0.9286
# Epoch 99/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9193 - accuracy: 0.7143
# Epoch 100/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7880 - accuracy: 0.7381
# Epoch 101/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8037 - accuracy: 0.7857
# Epoch 102/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6604 - accuracy: 0.8571
# Epoch 103/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6883 - accuracy: 0.9286
# Epoch 104/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6859 - accuracy: 0.8571
# Epoch 105/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6748 - accuracy: 0.9286
# Epoch 106/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6752 - accuracy: 0.8095
# Epoch 107/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6618 - accuracy: 0.9048
# Epoch 108/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6588 - accuracy: 0.8571
# Epoch 109/200
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.8333
# Epoch 110/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5976 - accuracy: 0.8810
# Epoch 111/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6347 - accuracy: 0.9286
# Epoch 112/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5859 - accuracy: 0.8810
# Epoch 113/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5608 - accuracy: 0.9048
# Epoch 114/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6598 - accuracy: 0.8810
# Epoch 115/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6491 - accuracy: 0.8333
# Epoch 116/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6222 - accuracy: 0.8571
# Epoch 117/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6098 - accuracy: 0.8810
# Epoch 118/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6131 - accuracy: 0.8333
# Epoch 119/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4748 - accuracy: 0.9048
# Epoch 120/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5590 - accuracy: 0.8571
# Epoch 121/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5554 - accuracy: 0.9286
# Epoch 122/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5337 - accuracy: 0.8810
# Epoch 123/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5085 - accuracy: 0.9286
# Epoch 124/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5436 - accuracy: 0.8571
# Epoch 125/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4497 - accuracy: 0.8810
# Epoch 126/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5755 - accuracy: 0.8810
# Epoch 127/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4218 - accuracy: 0.9286
# Epoch 128/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5639 - accuracy: 0.8810
# Epoch 129/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5077 - accuracy: 0.8810
# Epoch 130/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5367 - accuracy: 0.9048
# Epoch 131/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4590 - accuracy: 0.8810
# Epoch 132/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5112 - accuracy: 0.8810
# Epoch 133/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5473 - accuracy: 0.8810
# Epoch 134/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4541 - accuracy: 0.8810
# Epoch 135/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4152 - accuracy: 0.9048
# Epoch 136/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4433 - accuracy: 0.9524
# Epoch 137/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3932 - accuracy: 0.8810
# Epoch 138/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4183 - accuracy: 0.9286
# Epoch 139/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3770 - accuracy: 0.9524
# Epoch 140/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4410 - accuracy: 0.8810
# Epoch 141/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4617 - accuracy: 0.9286
# Epoch 142/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4626 - accuracy: 0.8810
# Epoch 143/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3937 - accuracy: 0.9048
# Epoch 144/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3323 - accuracy: 0.9048
# Epoch 145/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3645 - accuracy: 0.8810
# Epoch 146/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3824 - accuracy: 0.9286
# Epoch 147/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4040 - accuracy: 0.9286
# Epoch 148/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3363 - accuracy: 0.9524
# Epoch 149/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5180 - accuracy: 0.8571
# Epoch 150/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3971 - accuracy: 0.9048
# Epoch 151/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4146 - accuracy: 0.9286
# Epoch 152/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3418 - accuracy: 0.9524
# Epoch 153/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4410 - accuracy: 0.8810
# Epoch 154/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3599 - accuracy: 0.8571
# Epoch 155/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4381 - accuracy: 0.9048
# Epoch 156/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3446 - accuracy: 0.9048
# Epoch 157/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3823 - accuracy: 0.9048
# Epoch 158/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4573 - accuracy: 0.8571
# Epoch 159/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3374 - accuracy: 0.8810
# Epoch 160/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4190 - accuracy: 0.8571
# Epoch 161/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3957 - accuracy: 0.9048
# Epoch 162/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2197 - accuracy: 0.9762
# Epoch 163/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3344 - accuracy: 0.9524
# Epoch 164/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2586 - accuracy: 0.9286
# Epoch 165/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.9524
# Epoch 166/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2706 - accuracy: 0.9524
# Epoch 167/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3253 - accuracy: 0.9048
# Epoch 168/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3001 - accuracy: 0.9286
# Epoch 169/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3942 - accuracy: 0.8810
# Epoch 170/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2909 - accuracy: 0.9524
# Epoch 171/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3136 - accuracy: 0.9286
# Epoch 172/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3462 - accuracy: 0.9762
# Epoch 173/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3953 - accuracy: 0.8571
# Epoch 174/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2799 - accuracy: 0.9524
# Epoch 175/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2276 - accuracy: 0.9524
# Epoch 176/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3796 - accuracy: 0.8810
# Epoch 177/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2628 - accuracy: 0.9524
# Epoch 178/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2322 - accuracy: 0.9286
# Epoch 179/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3021 - accuracy: 0.8571
# Epoch 180/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2986 - accuracy: 0.9286
# Epoch 181/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3892 - accuracy: 0.8810
# Epoch 182/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2906 - accuracy: 0.9524
# Epoch 183/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2729 - accuracy: 0.9048
# Epoch 184/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3513 - accuracy: 0.9048
# Epoch 185/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2658 - accuracy: 0.9286
# Epoch 186/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2427 - accuracy: 0.9048
# Epoch 187/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3631 - accuracy: 0.9048
# Epoch 188/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3107 - accuracy: 0.9286
# Epoch 189/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2929 - accuracy: 0.9048
# Epoch 190/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2534 - accuracy: 0.9286
# Epoch 191/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3349 - accuracy: 0.8810
# Epoch 192/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2630 - accuracy: 0.9048
# Epoch 193/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3991 - accuracy: 0.8810
# Epoch 194/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2684 - accuracy: 0.9524
# Epoch 195/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1956 - accuracy: 0.9762
# Epoch 196/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2971 - accuracy: 0.9286
# Epoch 197/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2756 - accuracy: 0.9048
# Epoch 198/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2637 - accuracy: 0.9286
# Epoch 200/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2545 - accuracy: 0.9524

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
plt.show()

# %%
# Guardar lo necesario para poder re-utilizar este modelo en el futuro
# el vocabulario utilizado (words)
# las posibles clases
# el modelo
import pickle
pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))
model.save('chatbot_model.h5')

# %% [markdown]
# ### 6 - Testing y validación

# %%
# convertir texto de entrada del usuario a tokens
def text_to_tokens(text):
    lemma_tokens = []
    tokens = nlp(preprocess_clean_text(text.lower()))
    for token in tokens:
        lemma_tokens.append(token.lemma_)
    #print(lemma_tokens)
    return lemma_tokens

# transformar el texto de entrada tokenizado a una representación OHE
def bag_of_words(text, vocab): 
    tokens = text_to_tokens(text)
    bow = [0] * len(vocab)
    for w in tokens: 
        for idx, word in enumerate(vocab):
            if word == w: 
                bow[idx] = 1
    #print(bow)
    return np.array(bow)

# usar modelo con la entrada en OHE y los labels posibles (tags)
def pred_class(text, vocab, labels): 
    bow = bag_of_words(text, vocab)
    words_recognized = sum(bow)

    return_list = []
    if words_recognized > 0: # sólo si reconoció alguna palabra del vocabulario
        result = model.predict(np.array([bow]))[0] # es un array de softmax
        thresh = 0.2
        # filtrar aquellas entradas menores al umbral `thresh`
        y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]
        # ordenar keys de acuerdo al valor softmax
        y_pred.sort(key=lambda x: x[1], reverse=True)
    
        # return_list es una lista de los labels de mayor a menor
        for r in y_pred:
            return_list.append(labels[r[0]])
            #print(labels[r[0]], r[1])

    # si no reconoció palabras del vocabulario se devuelve una lista vacía
    return return_list

# obtener una respuesta predeterminada 
def get_response(intents_list, intents_json):
    tag = intents_list[0] # tomar el tag con el mejor valor softmax
    list_of_intents = intents_json["intents"] # intents_json es todo el dataset
    for i in list_of_intents: 
        if i["tag"] == tag: # buscar el tag correspoindiente y dar una respuesta predeterminada aleatoria 
            result = random.choice(i["responses"])
            break
    return result

# %%
while True:
    # pedir input al usuario
    message = input("")
    print("Q:", message)

    intents = pred_class(message, words, classes)
    if len(intents) > 0:
        result = get_response(intents, dataset)
        print("BOT:", result)
    else: # si no hubo ningún resultado que supere el umbral
        print("BOT: Perdón, no comprendo la pregunta.")
# Out:
# Hola, buen dia
# Q: Hola, buen dia
# 1/1 [==============================] - 0s 21ms/step
# BOT: Buen dia, ¿Cómo estás?
# estoy averiguando por palieres
# Q: estoy averiguando por palieres
# 1/1 [==============================] - 0s 19ms/step
# BOT: Si, ¿para que categoria?
# es para un auto de picadas
# Q: es para un auto de picadas
# 1/1 [==============================] - 0s 21ms/step
# BOT: ok, algunos modelos los tenemos en stock, otros los fabricamos segun muestra
# ok, como debo hacer para encargarlos?
# Q: ok, como debo hacer para encargarlos?
# /usr/local/lib/python3.7/dist-packages/stanza/models/common/beam.py:86: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   prevK = bestScoresId // numWords
# 1/1 [==============================] - 0s 25ms/step
# BOT: Necesitamos la muestra para poder fabricarlo
# ok, plazo?
# Q: ok, plazo?
# 1/1 [==============================] - 0s 18ms/step
# BOT: En material estandar 15 dias, en material PRO 25 dias
# bien, me podrias pasar el precio?
# Q: bien, me podrias pasar el precio?
# 1/1 [==============================] - 0s 22ms/step
# BOT: En el siguiente link podrás encontrar los precios de todos nuestros productos en stock
# ok, muchas gracias
# Q: ok, muchas gracias
# 1/1 [==============================] - 0s 22ms/step
# BOT: Por nada!, cualquier otra consulta podes escribirme
# chau
# Q: chau
# 1/1 [==============================] - 0s 18ms/step
# BOT: Hasta luego!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a132b4d00fe1> in <module>
#       1 while True:
#       2     # pedir input al usuario
# ----> 3     message = input("")
#       4     print("Q:", message)
#       5
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# El BOT generado responde de manera acertada las preguntas sobre la venta de un producto, en este caso palieres de autos de competicion.
